# %% [markdown]
# <a href="https://colab.research.google.com/github/fesaez/jupyter/blob/master/herancaclassesPOO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from abc import ABC, abstractmethod

# %%
class conta(ABC):

  def __init__(self, numero_da_conta, saldo):
    self.numero_da_conta = numero_da_conta
    self.saldo = saldo

  def depositar(self, valor):
    self.saldo += valor

  @abstractmethod
  def sacar(self, valor):
      raise NotImplementedError

# %%
class ContaPoupanca(conta):
  def sacar(self, valor):
    if self.saldo - valor > 0:
        self.saldo -= valor

  def calcular_rendimentos(self):
      self.saldo += self.saldo * 0.05

# %%
cp = ContaPoupanca(numero_da_conta = 123456, saldo=200)

# %%
cp. depositar(100)
cp.saldo
# Out:
# 300

# %%
cp.sacar(50)
cp.saldo
# Out:
# 250
